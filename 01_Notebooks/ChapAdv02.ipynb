# %% [markdown]
# # Advanced Topic - Working with Web Data

# %% [markdown]
# # inetdata.py

# %%
# 
# Retrieving data from URL
#

import urllib.request 

def main():

    # open a connection to a URL using urllib2
    webUrl = urllib.request.urlopen("http://www.google.com")
    
    # get the result code and print it
    print ("result code: " + str(webUrl.getcode()))
    
    # read the data from the URL and print it
    data = webUrl.read()
    print (data)

if __name__ == '__main__' : main()

# %% [markdown]
# # jsondata.py

# %%
# 
# Parsing and Processing JSON
#

import urllib.request
import json

def printResults(data):
    # Use the json module to load the string data into a dictionary
    theJSON = json.loads(data)
    # now we can access the contents of the JSON like any other Python object
    if "title" in theJSON["metadata"]:
        print (theJSON["metadata"]["title"])
        
    # output the number of events, plus the magnitude and each event name  
    count = theJSON["metadata"]["count"];
    print (str(count) + " events recorded")
    # for each event, print the place where it occurred
    for i in theJSON["features"]:
        print (i["properties"]["place"])
    print ("--------------\n")

    # print the events that only have a magnitude greater than 4
    for i in theJSON["features"]:
        if i["properties"]["mag"] >= 4.0:
            print ("%2.1f" % i["properties"]["mag"], i["properties"]["place"])
    print ("--------------\n")

    # print only the events where at least 1 person reported feeling something
    print ("\n\nEvents that were felt:")
    for i in theJSON["features"]:
        feltReports = i["properties"]["felt"]
        if (feltReports != None):
            if (feltReports > 0):
                print ("%2.1f" % i["properties"]["mag"], i["properties"]["place"], " reported " + str(feltReports) + " times")

def main():
    # define a variable to hold the source URL (data feed from the USGS)
    # This feed lists all earthquakes for the last day larger than Mag 2.5    
    urlData = "http://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/2.5_day.geojson"
    
    webUrl = urllib.request.urlopen(urlData)
    print ("result code: " + str(webUrl.getcode()))
    if (webUrl.getcode() == 200):
        data = webUrl.read()
        # print out our customized results
        printResults(data)
    else:
        print ("Received an error from server, cannot retrieve results " + str(webUrl.getcode()))

if __name__ == "__main__": main()
# Out:
# result code: 200
# USGS Magnitude 2.5+ Earthquakes, Past Day
# 40 events recorded
# 18km SE of Volcano, Hawaii
# 60km SE of Rudum, Yemen
# 179km S of Besisora, Indonesia
# 34km W of Anchorage, Alaska
# 21km SE of Riosucio, Colombia
# 125km W of Aksu, China
# 155km NE of Ndoi Island, Fiji
# 94km W of Larsen Bay, Alaska
# 72km WSW of Alberto Oviedo Mota, B.C., MX
# 62km SSW of Yonakuni, Japan
# 15km SSW of Olancha, CA
# 10km W of Newcastle, Oklahoma
# 93km NW of Skagway, Alaska
# 72km SE of Pondaguitan, Philippines
# 74km N of Tierras Nuevas Poniente, Puerto Rico
# Southern East Pacific Rise
# 115km NNW of Arctic Village, Alaska
# 11km S of Wilson, Oklahoma
# 42km E of Ishinomaki, Japan
# 49km NNE of Chilecito, Argentina
# 13km NW of Trion, Georgia
# 276km N of Ndoi Island, Fiji
# 182km ESE of Tadine, New Caledonia
# 58km NNE of Palu, Indonesia
# South of the Fiji Islands
# 83km W of Anchor Point, Alaska
# 115km NNW of Arctic Village, Alaska
# 108km NNW of Arctic Village, Alaska
# 111km NNW of Arctic Village, Alaska
# 51km NE of Honoka'a, Hawaii
# 124km NNW of Arctic Village, Alaska
# 96km W of Ile Hunter, New Caledonia
# 57km SW of Yonakuni, Japan
# 15km SSW of Honaunau-Napoopoo, Hawaii
# 34km SSW of Gueiria, Venezuela
# 66km SSW of Kaktovik, Alaska
# 128km NNE of Vieques, Puerto Rico
# 243km W of Petrolia, CA
# 123km WNW of Hofn, Iceland
# 84km NE of Miches, Dominican Republic
# --------------
#
# 4.7 60km SE of Rudum, Yemen
# 4.4 179km S of Besisora, Indonesia
# 4.8 21km SE of Riosucio, Colombia
# 4.7 125km W of Aksu, China
# 4.6 155km NE of Ndoi Island, Fiji
# 5.7 62km SSW of Yonakuni, Japan
# 4.4 72km SE of Pondaguitan, Philippines
# 5.2 Southern East Pacific Rise
# 4.6 42km E of Ishinomaki, Japan
# 4.5 49km NNE of Chilecito, Argentina
# 4.3 276km N of Ndoi Island, Fiji
# 4.4 182km ESE of Tadine, New Caledonia
# 4.3 58km NNE of Palu, Indonesia
# 4.7 South of the Fiji Islands
# 5.2 96km W of Ile Hunter, New Caledonia
# 5.7 57km SW of Yonakuni, Japan
# 4.9 34km SSW of Gueiria, Venezuela
# 4.5 123km WNW of Hofn, Iceland
# --------------
#
#
#
# Events that were felt:
# 5.7 62km SSW of Yonakuni, Japan  reported 20 times
# 2.6 10km W of Newcastle, Oklahoma  reported 15 times
# 3.4 11km S of Wilson, Oklahoma  reported 6 times
# 4.6 42km E of Ishinomaki, Japan  reported 2 times
# 5.7 57km SW of Yonakuni, Japan  reported 42 times
# 2.6 15km SSW of Honaunau-Napoopoo, Hawaii  reported 1 times
# 4.9 34km SSW of Gueiria, Venezuela  reported 9 times
